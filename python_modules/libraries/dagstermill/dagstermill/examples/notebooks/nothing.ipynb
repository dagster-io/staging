# %%
import dagstermill

# %%
num = 5

# %%
context = dagstermill.get_context()
context.log.info(f"{num}")
try:
    context.log.info(f"{nothing}")
except NameError:
    pass
else:
    assert False
# Out:
# 2021-01-22 12:15:57 - dagster - INFO - system - 74ee50bb-286b-4eac-abd8-05bdc4c101c1 - 5
# 2021-01-22 12:15:57 - dagster - INFO - system - 74ee50bb-286b-4eac-abd8-05bdc4c101c1 - None

# %%
dagstermill.yield_result(num)
# Out:
# 5
