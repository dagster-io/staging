# %%
import dagstermill

# %%
context = dagstermill.get_context()
solid_tags = context.solid_def.tags

# %%
assert "kind" in solid_tags
assert "notebook_path" in solid_tags
dagstermill.yield_result(solid_tags.get("metadata"))
