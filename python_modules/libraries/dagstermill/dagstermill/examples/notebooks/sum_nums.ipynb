# %%
import dagstermill
# Out:
# 2021-01-12 11:07:40 - dagster - ERROR - system - f8d7f3b7-ffa6-444a-a556-1da47616c84b - cell 1

# %%
nums = [1, 2, 3]

# %%
context = dagstermill.get_context()
context.log.error(f"{nums}")
# Out:
# [1, 2, 3]

# %%
result = sum(nums)
result
# Out:
# 2021-01-12 11:07:47 - dagster - ERROR - system - f8d7f3b7-ffa6-444a-a556-1da47616c84b - cell 3
# 6

# %%
dagstermill.yield_result(result)
# Out:
# 6
